# %%
import pandas as pd
from scikit_posthocs import posthoc_dunn as pdunn

# %%
data = pd.read_excel("/Users/adrienkouanda/Documents/ETUDIANTS/EDJENGUELE/data_1.xlsx")

# %%
data
# Out:
#      Numéro_de_fiche  Age_en_année Tranche_age      Sexe Diabète  HTA  \
# 0                  1            62       58-67  Masculin     Non  Oui
# 1                  2            46       38-47   Féminin     Non  Non
# 2                  3            60       58-67  Masculin     Non  Non
# 3                  4            58       58-67  Masculin     Oui  Oui
# 4                  5            73        >=68   Féminin     Non  Non
# ..               ...           ...         ...       ...     ...  ...
# 385              388            55       48-57  Masculin     Non  Non
# 386              392            51       48-57  Masculin     Non  Oui
# 387              390            42       38-47   Féminin     Non  Non
# 388              391            51       48-57   Féminin     Non  Non
# 389              389            30       28-37  Masculin     Non  Non
#
#     Maladie_rénale_chronique Infection_a_VIH Cancer Hépatite  ...  \
# ...

# %%
res = pdunn(data,val_col="Age_en_année",group_col="Tranche_age")

# %%
res
# Out:
#               18-27         28-37         38-47         48-57         58-67  \
# 18-27  1.000000e+00  1.195763e-01  2.325452e-04  2.257196e-12  3.495948e-30
# 28-37  1.195763e-01  1.000000e+00  3.898786e-02  7.854623e-08  7.377944e-23
# 38-47  2.325452e-04  3.898786e-02  1.000000e+00  5.533470e-04  7.641016e-17
# 48-57  2.257196e-12  7.854623e-08  5.533470e-04  1.000000e+00  9.797252e-08
# 58-67  3.495948e-30  7.377944e-23  7.641016e-17  9.797252e-08  1.000000e+00
# >=68   4.963221e-50  3.507141e-41  8.455712e-35  6.041519e-23  3.560169e-07
#
#                >=68
# 18-27  4.963221e-50
# 28-37  3.507141e-41
# 38-47  8.455712e-35
# 48-57  6.041519e-23
# 58-67  3.560169e-07
# >=68   1.000000e+00

# %%
"""rien du tout """ + """   
hghg
hghg
jkhkjh

"""
# Out:
# 'rien du tout    \nhghg\nhghg\njkhkjh\n\n'
